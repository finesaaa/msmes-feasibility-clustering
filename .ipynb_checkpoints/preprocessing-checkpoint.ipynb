# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import os
import glob
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score
import scipy.cluster.hierarchy as shc
from sklearn import preprocessing
import datetime

# exploratory data analysis
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Exploratory Data Analysis

# %%
FILE_INPUT = './output/all_data_combined.csv'
df_all = pd.read_csv(FILE_INPUT)
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                                            Onclick  \
# 0             2011  ?pm=RpTBuwFXpk0U+svpbtrrNw==&mp=Bjv3m4lcInn46O...
# 1             2014  ?pm=rjoizvPnwBFrInEOmzGGCg==&mp=xI6rAeQkygTAn3...
# 2             2012  ?pm=6qSIXAe2FXHSkx4JaHGCig==&mp=p1ca+Y2BZCwOZV...
# 3             2012  ?pm=PkfKI5UErkBEkyizF7P8RQ==&mp=p1ca+Y2BZCwOZV...
# 4             2011  ?pm=NlDG+tr8uWSJBncTyO62YA==&mp=Bjv3m4lcInn46O...
# ...            ...                                                ...
# 3907          2013  ?pm=aAn3y3aAVRAk2jA22WvOMA==&mp=fOhzApotY5QnAt...
# 3908          2012  ?pm=Uzb+RUOOyBwAgpStvd68zw==&mp=p1ca+Y2BZCwOZV...
# 3909          2014  ?pm=i+QsDPAbnhOVkkq3ryh1nA==&mp=xI6rAeQkygTAn3...
# 3910          2014  ?pm=Ap/omNIg7Sjp88sSosQkXw==&mp=xI6rAeQkygTAn3...
# 3911          2014  ?pm=zuLy7wlseazGf2OM5MueJg==&mp=xI6rAeQkygTAn3...
#
#                                    Sektor Nama Badan Hukum  \
# 0     Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1     Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2     Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3     Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4     Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...                                   ...              ...
# 3907             Informasi dan Komunikasi       Perorangan
# 3908             Informasi dan Komunikasi       Perorangan
# 3909             Informasi dan Komunikasi       Perorangan
# 3910             Informasi dan Komunikasi       Perorangan
# 3911             Informasi dan Komunikasi       Perorangan
#
#       Jumlah Tenaga Kerja.1 Sistem Penjualan  \
# 0                       2.0           Retail
# 1                       3.0           Retail
# 2                       1.0           Retail
# 3                      12.0      Distributor
# 4                       3.0           Retail
# ...                     ...              ...
# 3907                    1.0           Retail
# 3908                    2.0           Retail
# 3909                    8.0           Retail
# 3910                    1.0           Retail
# 3911                    2.0           Retail
#
#                       Target Pasar Utama : Produk Masal  \
# 0     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 1     Masyarakat Golongan Menengah (penghasilan Rp 5...
# 2     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3     Masyarakat Golongan Atas (penghasilan lebih da...
# 4     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# ...                                                 ...
# 3907  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3908  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3909  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3910  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3911  Masyarakat Golongan Menengah (penghasilan Rp 5...
#
#                    Target Pasar Utama : Produk Spesifik Tingkat Pesaing Usaha  \
# 0     Masyarakat Golongan Menengah (penghasilan Rp 5...                Sedang
# 1                                    Tidak Ada   0,00 %                Sedang
# 2     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Tinggi
# 3                                    Tidak Ada   0,00 %                Rendah
# 4     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# ...                                                 ...                   ...
# 3907  Masyarakat Golongan Menengah (penghasilan Rp 5...                Rendah
# 3908  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# 3909                               Tidak Ada Â  0,00Â %                Tinggi
# 3910                               Tidak Ada Â  0,00Â %                Sedang
# 3911                               Tidak Ada Â  0,00Â %                Rendah
#
#                    Total Aset Penjualan Rata-Rata per Tahun  \
# 0               Rp. 5,00 Juta                Rp. 48,00 Juta
# 1              Rp. 71,50 Juta                Rp. 60,00 Juta
# 2               Rp. 0,00 Juta                 Rp. 0,00 Juta
# 3              Rp. 13,00 Juta               Rp. 402,00 Juta
# 4              Rp. 89,00 Juta               Rp. 600,00 Juta
# ...                       ...                           ...
# 3907  Rp. 314.000.000,00 Juta        Rp. 40.000.000,00 Juta
# 3908            Rp. 0,00 Juta                 Rp. 0,00 Juta
# 3909           Rp. 54,00 Juta                Rp. 35,00 Juta
# 3910            Rp. 4,60 Juta                Rp. 30,00 Juta
# 3911           Rp. 23,30 Juta                Rp. 92,40 Juta
#
#      Proyeksi Pertumbuhan Penjualan Kebutuhan Pembiayaan Kredit   \
# 0                        10 %/Tahun                Rp. 5,00 Juta
# 1                        10 %/Tahun               Rp. 10,00 Juta
# 2                         0 %/Tahun                Rp. 5,00 Juta
# 3                         2 %/Tahun                Rp. 8,00 Juta
# 4                        10 %/Tahun               Rp. 10,00 Juta
# ...                             ...                          ...
# 3907                     10 %/Tahun               Rp. 10,00 Juta
# 3908                      0 %/Tahun               Rp. 10,00 Juta
# 3909                      - %/Tahun                Rp. 1,00 Juta
# 3910                      - %/Tahun               Rp. 10,00 Juta
# 3911                      - %/Tahun                Rp. 5,00 Juta
#
#      Nilai Aset yang data menjadi jaminan kredit  \
# 0                                  Rp. 4,00 Juta
# 1                                Rp. 200,00 Juta
# 2                                  Rp. 6,00 Juta
# 3                                 Rp. 10,00 Juta
# 4                                 Rp. 24,00 Juta
# ...                                          ...
# 3907                             Rp. 158,00 Juta
# 3908                              Rp. 12,00 Juta
# 3909                             Rp. 120,00 Juta
# 3910                             Rp. 150,00 Juta
# 3911                              Rp. 12,00 Juta
#
#      Jumlah Dokumen Persyaratan Kredit  Unnamed: 0
# 0                                    4         NaN
# 1                                    3         NaN
# 2                                    7         NaN
# 3                                    5         NaN
# 4                                    4         NaN
# ...                                ...         ...
# 3907                                 9         NaN
# 3908                                 4         NaN
# 3909                                 1         NaN
# 3910                                 2         NaN
# 3911                                 3         NaN
#
# [3912 rows x 20 columns]

# %%
df_all.drop(['Onclick', 'Unnamed: 0'], axis=1, inplace=True)

# %%
# list of columns
df_all.columns
# Out:
# Index(['Usaha /Produk Utama', 'Total Aset (Rp. Juta)',
#        'Penjualan Rata-rata Per Tahun (Rp.Juta)', 'Jumlah Tenaga Kerja',
#        'Tahun Survey', 'Sektor', 'Nama Badan Hukum', 'Jumlah Tenaga Kerja.1',
#        'Sistem Penjualan', 'Target Pasar Utama : Produk Masal',
#        'Target Pasar Utama : Produk Spesifik', 'Tingkat Pesaing Usaha',
#        'Total Aset', 'Penjualan Rata-Rata per Tahun',
#        'Proyeksi Pertumbuhan Penjualan', 'Kebutuhan Pembiayaan Kredit ',
#        'Nilai Aset yang data menjadi jaminan kredit',
#        'Jumlah Dokumen Persyaratan Kredit'],
#       dtype='object')

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3912 entries, 0 to 3911
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Usaha /Produk Utama                          3911 non-null   object
#  1   Total Aset (Rp. Juta)                        3912 non-null   object
#  2   Penjualan Rata-rata Per Tahun (Rp.Juta)      3912 non-null   object
#  3   Jumlah Tenaga Kerja                          3912 non-null   int64
#  4   Tahun Survey                                 3912 non-null   int64
#  5   Sektor                                       3912 non-null   object
#  6   Nama Badan Hukum                             3786 non-null   object
#  7   Jumlah Tenaga Kerja.1                        3786 non-null   float64
#  8   Sistem Penjualan                             3786 non-null   object
#  9   Target Pasar Utama : Produk Masal            3912 non-null   object
#  10  Target Pasar Utama : Produk Spesifik         3912 non-null   object
#  11  Tingkat Pesaing Usaha                        3786 non-null   object
#  12  Total Aset                                   3912 non-null   object
#  13  Penjualan Rata-Rata per Tahun                3912 non-null   object
#  14  Proyeksi Pertumbuhan Penjualan               3912 non-null   object
#  15  Kebutuhan Pembiayaan Kredit                  3912 non-null   object
#  16  Nilai Aset yang data menjadi jaminan kredit  3912 non-null   object
#  17  Jumlah Dokumen Persyaratan Kredit            3786 non-null   object
# dtypes: float64(1), int64(2), object(15)
# memory usage: 550.2+ KB

# %%
df_all.drop_duplicates(inplace=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 3911
# Data columns (total 18 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Usaha /Produk Utama                          2996 non-null   object
#  1   Total Aset (Rp. Juta)                        2997 non-null   object
#  2   Penjualan Rata-rata Per Tahun (Rp.Juta)      2997 non-null   object
#  3   Jumlah Tenaga Kerja                          2997 non-null   int64
#  4   Tahun Survey                                 2997 non-null   int64
#  5   Sektor                                       2997 non-null   object
#  6   Nama Badan Hukum                             2891 non-null   object
#  7   Jumlah Tenaga Kerja.1                        2891 non-null   float64
#  8   Sistem Penjualan                             2891 non-null   object
#  9   Target Pasar Utama : Produk Masal            2997 non-null   object
#  10  Target Pasar Utama : Produk Spesifik         2997 non-null   object
#  11  Tingkat Pesaing Usaha                        2891 non-null   object
#  12  Total Aset                                   2997 non-null   object
#  13  Penjualan Rata-Rata per Tahun                2997 non-null   object
#  14  Proyeksi Pertumbuhan Penjualan               2997 non-null   object
#  15  Kebutuhan Pembiayaan Kredit                  2997 non-null   object
#  16  Nilai Aset yang data menjadi jaminan kredit  2997 non-null   object
#  17  Jumlah Dokumen Persyaratan Kredit            2891 non-null   object
# dtypes: float64(1), int64(2), object(15)
# memory usage: 444.9+ KB

# %% [markdown]
# ### Converting String to Numeric

# %%
# fungsi bantuan untuk mengkonversi fitur menjadi data type integer
import numpy as np
def convert_to_int_helper(feature):
    try:
        return int(feature)
    except:
        return np.nan

# %%
df_all['Jumlah Dokumen Persyaratan Kredit'] = df_all['Jumlah Dokumen Persyaratan Kredit'].apply(convert_to_int_helper)

# %%
kolom_rup=['Kebutuhan Pembiayaan Kredit ','Nilai Aset yang data menjadi jaminan kredit']

for kolom in kolom_rup:
    df_all[kolom] = df_all[kolom].str.replace('Rp. ', '').str.replace(' ', '').str.replace('Juta', '')
    df_all[kolom] = df_all[kolom].str.replace(',00', '')
# Out:
# C:\Users\indri\AppData\Local\Temp\ipykernel_6200\752859276.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_all[kolom] = df_all[kolom].str.replace('Rp. ', '').str.replace(' ', '').str.replace('Juta', '')

# %%
df_all['Kebutuhan Pembiayaan Kredit '] = df_all['Kebutuhan Pembiayaan Kredit '].apply(convert_to_int_helper)
df_all['Nilai Aset yang data menjadi jaminan kredit'] = df_all['Nilai Aset yang data menjadi jaminan kredit'].apply(convert_to_int_helper)

# %%
df_all.drop(columns=["Total Aset", "Penjualan Rata-Rata per Tahun", "Jumlah Tenaga Kerja.1"], inplace=True)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan                  Target Pasar Utama : Produk Masal  \
# 0              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 1              Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 2              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3         Distributor  Masyarakat Golongan Atas (penghasilan lebih da...
# 4              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# ...               ...                                                ...
# 3907           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3908           Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3909           Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3910           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3911           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
#
#                    Target Pasar Utama : Produk Spesifik Tingkat Pesaing Usaha  \
# 0     Masyarakat Golongan Menengah (penghasilan Rp 5...                Sedang
# 1                                    Tidak Ada   0,00 %                Sedang
# 2     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Tinggi
# 3                                    Tidak Ada   0,00 %                Rendah
# 4     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# ...                                                 ...                   ...
# 3907  Masyarakat Golongan Menengah (penghasilan Rp 5...                Rendah
# 3908  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# 3909                               Tidak Ada Â  0,00Â %                Tinggi
# 3910                               Tidak Ada Â  0,00Â %                Sedang
# 3911                               Tidak Ada Â  0,00Â %                Rendah
#
#      Proyeksi Pertumbuhan Penjualan  Kebutuhan Pembiayaan Kredit   \
# 0                        10 %/Tahun                           5.0
# 1                        10 %/Tahun                          10.0
# 2                         0 %/Tahun                           5.0
# 3                         2 %/Tahun                           8.0
# 4                        10 %/Tahun                          10.0
# ...                             ...                           ...
# 3907                     10 %/Tahun                          10.0
# 3908                      0 %/Tahun                          10.0
# 3909                      - %/Tahun                           1.0
# 3910                      - %/Tahun                          10.0
# 3911                      - %/Tahun                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit
# 0                                   4.0
# 1                                   3.0
# 2                                   7.0
# 3                                   5.0
# 4                                   4.0
# ...                                 ...
# 3907                                9.0
# 3908                                4.0
# 3909                                1.0
# 3910                                2.0
# 3911                                3.0
#
# [2997 rows x 15 columns]

# %%
kolom_rup=['Proyeksi Pertumbuhan Penjualan']

for kolom in kolom_rup:
    df_all[kolom] = df_all[kolom].str.replace(' ', '').str.replace('%/Tahun', '')
    df_all[kolom] = df_all[kolom].apply(convert_to_int_helper)
    df_all[kolom] = df_all[kolom] / 100

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan                  Target Pasar Utama : Produk Masal  \
# 0              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 1              Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 2              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3         Distributor  Masyarakat Golongan Atas (penghasilan lebih da...
# 4              Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# ...               ...                                                ...
# 3907           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3908           Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3909           Retail  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...
# 3910           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
# 3911           Retail  Masyarakat Golongan Menengah (penghasilan Rp 5...
#
#                    Target Pasar Utama : Produk Spesifik Tingkat Pesaing Usaha  \
# 0     Masyarakat Golongan Menengah (penghasilan Rp 5...                Sedang
# 1                                    Tidak Ada   0,00 %                Sedang
# 2     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Tinggi
# 3                                    Tidak Ada   0,00 %                Rendah
# 4     Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# ...                                                 ...                   ...
# 3907  Masyarakat Golongan Menengah (penghasilan Rp 5...                Rendah
# 3908  Masyarakat Gol Bawah (penghasilan sd 5 juta/bu...                Sedang
# 3909                               Tidak Ada Â  0,00Â %                Tinggi
# 3910                               Tidak Ada Â  0,00Â %                Sedang
# 3911                               Tidak Ada Â  0,00Â %                Rendah
#
#       Proyeksi Pertumbuhan Penjualan  Kebutuhan Pembiayaan Kredit   \
# 0                               0.10                           5.0
# 1                               0.10                          10.0
# 2                               0.00                           5.0
# 3                               0.02                           8.0
# 4                               0.10                          10.0
# ...                              ...                           ...
# 3907                            0.10                          10.0
# 3908                            0.00                          10.0
# 3909                             NaN                           1.0
# 3910                             NaN                          10.0
# 3911                             NaN                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit
# 0                                   4.0
# 1                                   3.0
# 2                                   7.0
# 3                                   5.0
# 4                                   4.0
# ...                                 ...
# 3907                                9.0
# 3908                                4.0
# 3909                                1.0
# 3910                                2.0
# 3911                                3.0
#
# [2997 rows x 15 columns]

# %%
def separator(x):
    if 'gol bawah' in x.lower():
        return 'golongan bawah'
    elif 'golongan atas' in x.lower():
        return 'golongan atas'
    elif 'golongan menengah' in x.lower():
        return 'golongan menengah'
    elif 'memenuhi order' in x.lower():
        return 'memenuhi order distributor/exportir/trader'
    elif 'tidak ada'in x.lower():
        return 'tidak ada'
    else:
        return np.NaN

# %%
df_all['Sasaran Produk Massal'] = df_all['Target Pasar Utama : Produk Masal'].apply(separator)
df_all['Persentase Massal'] = df_all['Target Pasar Utama : Produk Masal'].apply(lambda x: str(x.split('\xa0')[-2])[:-3])
df_all['Sasaran Produk Spesifik'] = df_all['Target Pasar Utama : Produk Spesifik'].apply(separator)
df_all['Persentase Spesifik'] = df_all['Target Pasar Utama : Produk Spesifik'].apply(lambda x: str(x.split('\xa0')[-2])[:-3])

df_all.drop('Target Pasar Utama : Produk Masal', axis=1, inplace=True)
df_all.drop('Target Pasar Utama : Produk Spesifik', axis=1, inplace=True)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit Sasaran Produk Massal  \
# 0                                   4.0        golongan bawah
# 1                                   3.0     golongan menengah
# 2                                   7.0        golongan bawah
# 3                                   5.0         golongan atas
# 4                                   4.0        golongan bawah
# ...                                 ...                   ...
# 3907                                9.0     golongan menengah
# 3908                                4.0        golongan bawah
# 3909                                1.0        golongan bawah
# 3910                                2.0     golongan menengah
# 3911                                3.0     golongan menengah
#
#      Persentase Massal Sasaran Produk Spesifik Persentase Spesifik
# 0                  100       golongan menengah                   0
# 1                  100               tidak ada                   0
# 2                    0          golongan bawah                   0
# 3                  100               tidak ada                   0
# 4                  100          golongan bawah                   0
# ...                ...                     ...                 ...
# 3907              100,       golongan menengah                100,
# 3908               50,          golongan bawah                 50,
# 3909              100,               tidak ada                  0,
# 3910              100,               tidak ada                  0,
# 3911              100,               tidak ada                  0,
#
# [2997 rows x 17 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 3911
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Usaha /Produk Utama                          2996 non-null   object
#  1   Total Aset (Rp. Juta)                        2997 non-null   object
#  2   Penjualan Rata-rata Per Tahun (Rp.Juta)      2997 non-null   object
#  3   Jumlah Tenaga Kerja                          2997 non-null   int64
#  4   Tahun Survey                                 2997 non-null   int64
#  5   Sektor                                       2997 non-null   object
#  6   Nama Badan Hukum                             2891 non-null   object
#  7   Sistem Penjualan                             2891 non-null   object
#  8   Tingkat Pesaing Usaha                        2891 non-null   object
#  9   Proyeksi Pertumbuhan Penjualan               2446 non-null   float64
#  10  Kebutuhan Pembiayaan Kredit                  2793 non-null   float64
#  11  Nilai Aset yang data menjadi jaminan kredit  2910 non-null   float64
#  12  Jumlah Dokumen Persyaratan Kredit            2741 non-null   float64
#  13  Sasaran Produk Massal                        2891 non-null   object
#  14  Persentase Massal                            2997 non-null   object
#  15  Sasaran Produk Spesifik                      2891 non-null   object
#  16  Persentase Spesifik                          2997 non-null   object
# dtypes: float64(4), int64(2), object(11)
# memory usage: 421.5+ KB

# %%
import re
def remove_comma(data):
    if ',' in data:
        new_string = re.sub(r'[^\w\s]', '', data)
        return new_string
    else: return data
    
df_all['Persentase Massal'] = df_all['Persentase Massal'].apply(remove_comma)

# %%
df_all['Persentase Massal'] = df_all['Persentase Massal'].apply(convert_to_int_helper)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit Sasaran Produk Massal  \
# 0                                   4.0        golongan bawah
# 1                                   3.0     golongan menengah
# 2                                   7.0        golongan bawah
# 3                                   5.0         golongan atas
# 4                                   4.0        golongan bawah
# ...                                 ...                   ...
# 3907                                9.0     golongan menengah
# 3908                                4.0        golongan bawah
# 3909                                1.0        golongan bawah
# 3910                                2.0     golongan menengah
# 3911                                3.0     golongan menengah
#
#       Persentase Massal Sasaran Produk Spesifik Persentase Spesifik
# 0                 100.0       golongan menengah                   0
# 1                 100.0               tidak ada                   0
# 2                   0.0          golongan bawah                   0
# 3                 100.0               tidak ada                   0
# 4                 100.0          golongan bawah                   0
# ...                 ...                     ...                 ...
# 3907              100.0       golongan menengah                100,
# 3908               50.0          golongan bawah                 50,
# 3909              100.0               tidak ada                  0,
# 3910              100.0               tidak ada                  0,
# 3911              100.0               tidak ada                  0,
#
# [2997 rows x 17 columns]

# %%
df_all['Persentase Massal'].unique()
# Out:
# array([1.0e+02, 0.0e+00, 5.0e+01, 7.0e+01, 3.0e+01, 2.0e+01, 4.0e+01,
#        8.0e+01, 9.0e+01, 6.0e+01, 2.5e+01, 1.0e+01, 7.5e+01, 3.7e+01,
#        5.0e+00, 8.5e+01, 2.0e+00, 9.5e+01, 1.0e+04, 6.0e+03, 5.0e+03,
#        1.0e+03, 8.0e+03, 3.0e+03, 7.0e+03, 1.5e+03, 5.0e+02, 2.0e+03,
#        4.0e+03, 9.0e+03, 6.5e+03, 2.5e+03, 7.5e+03, 8.5e+03, 9.5e+03,
#        4.5e+03,     nan])

# %%
df_all['Persentase Spesifik'] = df_all['Persentase Spesifik'].apply(remove_comma)
df_all['Persentase Spesifik'] = df_all['Persentase Spesifik'].apply(convert_to_int_helper)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit Sasaran Produk Massal  \
# 0                                   4.0        golongan bawah
# 1                                   3.0     golongan menengah
# 2                                   7.0        golongan bawah
# 3                                   5.0         golongan atas
# 4                                   4.0        golongan bawah
# ...                                 ...                   ...
# 3907                                9.0     golongan menengah
# 3908                                4.0        golongan bawah
# 3909                                1.0        golongan bawah
# 3910                                2.0     golongan menengah
# 3911                                3.0     golongan menengah
#
#       Persentase Massal Sasaran Produk Spesifik  Persentase Spesifik
# 0                 100.0       golongan menengah                  0.0
# 1                 100.0               tidak ada                  0.0
# 2                   0.0          golongan bawah                  0.0
# 3                 100.0               tidak ada                  0.0
# 4                 100.0          golongan bawah                  0.0
# ...                 ...                     ...                  ...
# 3907              100.0       golongan menengah                100.0
# 3908               50.0          golongan bawah                 50.0
# 3909              100.0               tidak ada                  0.0
# 3910              100.0               tidak ada                  0.0
# 3911              100.0               tidak ada                  0.0
#
# [2997 rows x 17 columns]

# %%
def sasaran_produk(row):
    if(float(row['Persentase Massal'])>=50):
        val=row['Sasaran Produk Massal']
    else:
        val=row['Sasaran Produk Spesifik']
    return val

# %%
df_all['Sasaran Produk']=df_all.apply(sasaran_produk,axis=1)

# %%
df_all.drop('Sasaran Produk Massal', axis=1, inplace=True)
df_all.drop('Persentase Massal', axis=1, inplace=True)
df_all.drop('Sasaran Produk Spesifik', axis=1, inplace=True)
df_all.drop('Persentase Spesifik', axis=1, inplace=True)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit     Sasaran Produk
# 0                                   4.0     golongan bawah
# 1                                   3.0  golongan menengah
# 2                                   7.0     golongan bawah
# 3                                   5.0      golongan atas
# 4                                   4.0     golongan bawah
# ...                                 ...                ...
# 3907                                9.0  golongan menengah
# 3908                                4.0     golongan bawah
# 3909                                1.0     golongan bawah
# 3910                                2.0  golongan menengah
# 3911                                3.0  golongan menengah
#
# [2997 rows x 14 columns]

# %%
#delete tipo
df_all['Tahun Survey']=df_all['Tahun Survey'].replace(3012,2012)
df_all['Tahun Survey']=df_all['Tahun Survey'].replace(2913,2013)

#ganti - jadi null
df_all['Nama Badan Hukum']=df_all['Nama Badan Hukum'].replace('-',np.NaN)

df_all['Sistem Penjualan']=df_all['Sistem Penjualan'].replace('-',np.NaN)

df_all['Tingkat Pesaing Usaha']=df_all['Tingkat Pesaing Usaha'].replace('-',np.NaN)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71,5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK           314.000.000
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4,6
# 3911                     Pulsa                  23,3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                              40.000.000                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92,4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit     Sasaran Produk
# 0                                   4.0     golongan bawah
# 1                                   3.0  golongan menengah
# 2                                   7.0     golongan bawah
# 3                                   5.0      golongan atas
# 4                                   4.0     golongan bawah
# ...                                 ...                ...
# 3907                                9.0  golongan menengah
# 3908                                4.0     golongan bawah
# 3909                                1.0     golongan bawah
# 3910                                2.0  golongan menengah
# 3911                                3.0  golongan menengah
#
# [2997 rows x 14 columns]

# %%
df_all['Total Aset (Rp. Juta)']=df_all['Total Aset (Rp. Juta)'].str.replace(',','.')
df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)']=df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)'].str.replace(',','.')

# %%
def ganti_ganti(data):
    if len(data) > 6:
        data = float(data.replace(',','.').replace('.',''))
        data = data / 1000000
        
    return data

# %%
df_all['Total Aset (Rp. Juta)'] = df_all['Total Aset (Rp. Juta)'].apply(ganti_ganti)
df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)'] = df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)'].apply(ganti_ganti)

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71.5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK                 314.0
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4.6
# 3911                     Pulsa                  23.3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                                    40.0                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92.4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit     Sasaran Produk
# 0                                   4.0     golongan bawah
# 1                                   3.0  golongan menengah
# 2                                   7.0     golongan bawah
# 3                                   5.0      golongan atas
# 4                                   4.0     golongan bawah
# ...                                 ...                ...
# 3907                                9.0  golongan menengah
# 3908                                4.0     golongan bawah
# 3909                                1.0     golongan bawah
# 3910                                2.0  golongan menengah
# 3911                                3.0  golongan menengah
#
# [2997 rows x 14 columns]

# %%
df_all
# Out:
#            Usaha /Produk Utama Total Aset (Rp. Juta)  \
# 0                     Air Tebu                     5
# 1               Amplang Blitar                  71.5
# 2                      Bandrek                     0
# 3                    Bengkoang                    13
# 4            Beras Dan Sayuran                    89
# ...                        ...                   ...
# 3907  LOKET PEMBAYARAN LISTRIK                 314.0
# 3908                    Warnet                     0
# 3909                    Warnet                    54
# 3910           Penjualan Pulsa                   4.6
# 3911                     Pulsa                  23.3
#
#      Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                         48                    2
# 1                                         60                    3
# 2                                          0                    1
# 3                                        402                   12
# 4                                        600                    3
# ...                                      ...                  ...
# 3907                                    40.0                    1
# 3908                                       0                    2
# 3909                                      35                    8
# 3910                                      30                    1
# 3911                                    92.4                    2
#
#       Tahun Survey                               Sektor Nama Badan Hukum  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 1             2014  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 2             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 3             2012  Pertanian, Kehutanan, dan Perikanan       Perorangan
# 4             2011  Pertanian, Kehutanan, dan Perikanan       Perorangan
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi       Perorangan
# 3908          2012             Informasi dan Komunikasi       Perorangan
# 3909          2014             Informasi dan Komunikasi       Perorangan
# 3910          2014             Informasi dan Komunikasi       Perorangan
# 3911          2014             Informasi dan Komunikasi       Perorangan
#
#      Sistem Penjualan Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0              Retail                Sedang                            0.10
# 1              Retail                Sedang                            0.10
# 2              Retail                Tinggi                            0.00
# 3         Distributor                Rendah                            0.02
# 4              Retail                Sedang                            0.10
# ...               ...                   ...                             ...
# 3907           Retail                Rendah                            0.10
# 3908           Retail                Sedang                            0.00
# 3909           Retail                Tinggi                             NaN
# 3910           Retail                Sedang                             NaN
# 3911           Retail                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit     Sasaran Produk
# 0                                   4.0     golongan bawah
# 1                                   3.0  golongan menengah
# 2                                   7.0     golongan bawah
# 3                                   5.0      golongan atas
# 4                                   4.0     golongan bawah
# ...                                 ...                ...
# 3907                                9.0  golongan menengah
# 3908                                4.0     golongan bawah
# 3909                                1.0     golongan bawah
# 3910                                2.0  golongan menengah
# 3911                                3.0  golongan menengah
#
# [2997 rows x 14 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 3911
# Data columns (total 14 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Usaha /Produk Utama                          2996 non-null   object
#  1   Total Aset (Rp. Juta)                        2997 non-null   object
#  2   Penjualan Rata-rata Per Tahun (Rp.Juta)      2997 non-null   object
#  3   Jumlah Tenaga Kerja                          2997 non-null   int64
#  4   Tahun Survey                                 2997 non-null   int64
#  5   Sektor                                       2997 non-null   object
#  6   Nama Badan Hukum                             2890 non-null   object
#  7   Sistem Penjualan                             2879 non-null   object
#  8   Tingkat Pesaing Usaha                        2883 non-null   object
#  9   Proyeksi Pertumbuhan Penjualan               2446 non-null   float64
#  10  Kebutuhan Pembiayaan Kredit                  2793 non-null   float64
#  11  Nilai Aset yang data menjadi jaminan kredit  2910 non-null   float64
#  12  Jumlah Dokumen Persyaratan Kredit            2741 non-null   float64
#  13  Sasaran Produk                               2891 non-null   object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 351.2+ KB

# %%
#ubah tipe data
df_all = df_all.astype({'Total Aset (Rp. Juta)':'float','Penjualan Rata-rata Per Tahun (Rp.Juta)':'float'})

# %%
df_all = df_all[df_all['Nama Badan Hukum'].isin(['Perorangan', 'Usaha Dagang (UD)', np.NaN])]
df_all.drop('Nama Badan Hukum', axis=1, inplace=True)

# %%
df_all
# Out:
#            Usaha /Produk Utama  Total Aset (Rp. Juta)  \
# 0                     Air Tebu                    5.0
# 1               Amplang Blitar                   71.5
# 2                      Bandrek                    0.0
# 3                    Bengkoang                   13.0
# 4            Beras Dan Sayuran                   89.0
# ...                        ...                    ...
# 3907  LOKET PEMBAYARAN LISTRIK                  314.0
# 3908                    Warnet                    0.0
# 3909                    Warnet                   54.0
# 3910           Penjualan Pulsa                    4.6
# 3911                     Pulsa                   23.3
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                        48.0                    2
# 1                                        60.0                    3
# 2                                         0.0                    1
# 3                                       402.0                   12
# 4                                       600.0                    3
# ...                                       ...                  ...
# 3907                                     40.0                    1
# 3908                                      0.0                    2
# 3909                                     35.0                    8
# 3910                                     30.0                    1
# 3911                                     92.4                    2
#
#       Tahun Survey                               Sektor Sistem Penjualan  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan           Retail
# 1             2014  Pertanian, Kehutanan, dan Perikanan           Retail
# 2             2012  Pertanian, Kehutanan, dan Perikanan           Retail
# 3             2012  Pertanian, Kehutanan, dan Perikanan      Distributor
# 4             2011  Pertanian, Kehutanan, dan Perikanan           Retail
# ...            ...                                  ...              ...
# 3907          2013             Informasi dan Komunikasi           Retail
# 3908          2012             Informasi dan Komunikasi           Retail
# 3909          2014             Informasi dan Komunikasi           Retail
# 3910          2014             Informasi dan Komunikasi           Retail
# 3911          2014             Informasi dan Komunikasi           Retail
#
#      Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0                   Sedang                            0.10
# 1                   Sedang                            0.10
# 2                   Tinggi                            0.00
# 3                   Rendah                            0.02
# 4                   Sedang                            0.10
# ...                    ...                             ...
# 3907                Rendah                            0.10
# 3908                Sedang                            0.00
# 3909                Tinggi                             NaN
# 3910                Sedang                             NaN
# 3911                Rendah                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit     Sasaran Produk
# 0                                   4.0     golongan bawah
# 1                                   3.0  golongan menengah
# 2                                   7.0     golongan bawah
# 3                                   5.0      golongan atas
# 4                                   4.0     golongan bawah
# ...                                 ...                ...
# 3907                                9.0  golongan menengah
# 3908                                4.0     golongan bawah
# 3909                                1.0     golongan bawah
# 3910                                2.0  golongan menengah
# 3911                                3.0  golongan menengah
#
# [2967 rows x 13 columns]

# %%
df_all['Sektor'].value_counts()
# Out:
# Perdagangan Besar dan Eceran Reparasi dan Perawatan Mobil dan Sepeda Motor                                            1100
# Industri Pengolahan                                                                                                   1068
# Penyediaan Akomodasi dan Penyediaan Makan Minum                                                                        271
# Pertanian, Kehutanan, dan Perikanan                                                                                    253
# Kegiatan Jasa Lainnya                                                                                                  108
# Jasa Profesional, Ilmiah dan Teknis                                                                                     76
# Jasa Perorangan yg Melayani RT, Keg yg Menghasilkan Brg & Jasa oleh RT yg Digunakan Sendiri utk Memenuhi Kebutuhan      20
# Jasa Persewaan dan Sewa Guna Usaha Tanpa Hak Opsi, Ketenagakerjaan, Agen Perjalanan dan Penunjang Usaha Lainnya         14
# Konstruksi                                                                                                              13
# Kesenian, Hiburan dan Rekreasi                                                                                          11
# Informasi dan Komunikasi                                                                                                 9
# Pengadaan Air, Pengelolaan Sampah dan Daur Ulang, Pembuangan dan Pembersihan Limbah dan Sampah                           7
# Pengadaan Listrik, Gas, Uap Air Panas dan Udara Dingin                                                                   5
# Jasa Kesehatan dan Kegiatan Sosial                                                                                       4
# Transportasi dan Pergudangan                                                                                             3
# Jasa Pendidikan                                                                                                          2
# Jasa Keuangan dan Asuransi                                                                                               2
# Pertambangan dan Penggalian                                                                                              1
# Name: Sektor, dtype: int64

# %%
# sektor = pd.DataFrame(df_all['Sektor'].value_counts()>100).reset_index()
# sektorbesar = sektor[sektor['Sektor'] == True]['index'].tolist()
# df_all = df_all[df_all['Sektor'].isin(sektorbesar)]

# %%
def sektor_industri(row):
    if row['Sektor']=='Perdagangan Besar dan Eceran Reparasi dan Perawatan Mobil dan Sepeda Motor':
        val='Perdagangan dan Perawatan Kendaraan'
    elif row['Sektor']=='Industri Pengolahan':
        val='Industri Pengolahan'
    elif row['Sektor'] == 'Penyediaan Akomodasi dan Penyediaan Makan Minum':
        val='Penyediaan Akomodasi dan Penyediaan Makan Minum'
    elif row['Sektor'] == 'Pertanian, Kehutanan, dan Perikanan':
        val='Pertanian, Kehutanan, dan Perikanan'
    elif row['Sektor']==np.NaN:
        val=np.NaN
    else:
        val='Lain-lain'
    return val

# %%
df_all['Sektor']=df_all.apply(sektor_industri,axis=1)

# %%
df_all = df_all.replace({
    'Tingkat Pesaing Usaha' : { 'Rendah' : 2, 'Sedang' : 1, 'Tinggi' : 0},
    'Sasaran Produk' : { 'tidak ada' : 0, 'golongan bawah' : 1, 'golongan menengah' : 2, 'golongan atas' : 3,
                        'memenuhi order distributor/exportir/trader' : 4}})

# %%
df_all
# Out:
#            Usaha /Produk Utama  Total Aset (Rp. Juta)  \
# 0                     Air Tebu                    5.0
# 1               Amplang Blitar                   71.5
# 2                      Bandrek                    0.0
# 3                    Bengkoang                   13.0
# 4            Beras Dan Sayuran                   89.0
# ...                        ...                    ...
# 3907  LOKET PEMBAYARAN LISTRIK                  314.0
# 3908                    Warnet                    0.0
# 3909                    Warnet                   54.0
# 3910           Penjualan Pulsa                    4.6
# 3911                     Pulsa                   23.3
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                        48.0                    2
# 1                                        60.0                    3
# 2                                         0.0                    1
# 3                                       402.0                   12
# 4                                       600.0                    3
# ...                                       ...                  ...
# 3907                                     40.0                    1
# 3908                                      0.0                    2
# 3909                                     35.0                    8
# 3910                                     30.0                    1
# 3911                                     92.4                    2
#
#       Tahun Survey                               Sektor Sistem Penjualan  \
# 0             2011  Pertanian, Kehutanan, dan Perikanan           Retail
# 1             2014  Pertanian, Kehutanan, dan Perikanan           Retail
# 2             2012  Pertanian, Kehutanan, dan Perikanan           Retail
# 3             2012  Pertanian, Kehutanan, dan Perikanan      Distributor
# 4             2011  Pertanian, Kehutanan, dan Perikanan           Retail
# ...            ...                                  ...              ...
# 3907          2013                            Lain-lain           Retail
# 3908          2012                            Lain-lain           Retail
# 3909          2014                            Lain-lain           Retail
# 3910          2014                            Lain-lain           Retail
# 3911          2014                            Lain-lain           Retail
#
#       Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0                       1.0                            0.10
# 1                       1.0                            0.10
# 2                       0.0                            0.00
# 3                       2.0                            0.02
# 4                       1.0                            0.10
# ...                     ...                             ...
# 3907                    2.0                            0.10
# 3908                    1.0                            0.00
# 3909                    0.0                             NaN
# 3910                    1.0                             NaN
# 3911                    2.0                             NaN
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3907                          10.0
# 3908                          10.0
# 3909                           1.0
# 3910                          10.0
# 3911                           5.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3907                                        158.0
# 3908                                         12.0
# 3909                                        120.0
# 3910                                        150.0
# 3911                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit  Sasaran Produk
# 0                                   4.0             1.0
# 1                                   3.0             2.0
# 2                                   7.0             1.0
# 3                                   5.0             3.0
# 4                                   4.0             1.0
# ...                                 ...             ...
# 3907                                9.0             2.0
# 3908                                4.0             1.0
# 3909                                1.0             1.0
# 3910                                2.0             2.0
# 3911                                3.0             2.0
#
# [2967 rows x 13 columns]

# %%
df_all['Sektor'].unique()
# Out:
# array(['Pertanian, Kehutanan, dan Perikanan', 'Lain-lain',
#        'Industri Pengolahan', 'Perdagangan dan Perawatan Kendaraan',
#        'Penyediaan Akomodasi dan Penyediaan Makan Minum'], dtype=object)

# %%
df_all['Sektor'].value_counts()
# Out:
# Perdagangan dan Perawatan Kendaraan                1100
# Industri Pengolahan                                1068
# Lain-lain                                           275
# Penyediaan Akomodasi dan Penyediaan Makan Minum     271
# Pertanian, Kehutanan, dan Perikanan                 253
# Name: Sektor, dtype: int64

# %%
df_all['Sistem Penjualan'].value_counts()
# Out:
# Retail                    2158
# Retail dan Distributor     460
# Distributor                231
# Name: Sistem Penjualan, dtype: int64

# %%
df_all.replace({'Sistem Penjualan' : { 'Retail' : 1, 'Retail dan Distributor' : 2, 'Distributor' : 3}}, inplace=True)

# %%
df_all.drop(['Tahun Survey'],axis=1,inplace=True)

# %%
df_all.dropna(subset=['Sistem Penjualan', 'Tingkat Pesaing Usaha'],axis=0,inplace=True)

# %%
df_all.dropna(subset=['Proyeksi Pertumbuhan Penjualan'],axis=0,inplace=True)

# %%
df_all
# Out:
#            Usaha /Produk Utama  Total Aset (Rp. Juta)  \
# 0                     Air Tebu                   5.00
# 1               Amplang Blitar                  71.50
# 2                      Bandrek                   0.00
# 3                    Bengkoang                  13.00
# 4            Beras Dan Sayuran                  89.00
# ...                        ...                    ...
# 3904             Jasa Internet                  22.50
# 3905                Service TV                  16.50
# 3906                    WARNET                  90.95
# 3907  LOKET PEMBAYARAN LISTRIK                 314.00
# 3908                    Warnet                   0.00
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                        48.0                    2
# 1                                        60.0                    3
# 2                                         0.0                    1
# 3                                       402.0                   12
# 4                                       600.0                    3
# ...                                       ...                  ...
# 3904                                    704.0                    2
# 3905                                    115.0                    1
# 3906                                     94.5                    5
# 3907                                     40.0                    1
# 3908                                      0.0                    2
#
#                                    Sektor  Sistem Penjualan  \
# 0     Pertanian, Kehutanan, dan Perikanan               1.0
# 1     Pertanian, Kehutanan, dan Perikanan               1.0
# 2     Pertanian, Kehutanan, dan Perikanan               1.0
# 3     Pertanian, Kehutanan, dan Perikanan               3.0
# 4     Pertanian, Kehutanan, dan Perikanan               1.0
# ...                                   ...               ...
# 3904                            Lain-lain               1.0
# 3905                            Lain-lain               1.0
# 3906                            Lain-lain               1.0
# 3907                            Lain-lain               1.0
# 3908                            Lain-lain               1.0
#
#       Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0                       1.0                            0.10
# 1                       1.0                            0.10
# 2                       0.0                            0.00
# 3                       2.0                            0.02
# 4                       1.0                            0.10
# ...                     ...                             ...
# 3904                    0.0                            0.20
# 3905                    1.0                            0.10
# 3906                    1.0                            0.80
# 3907                    2.0                            0.10
# 3908                    1.0                            0.00
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 3904                          10.0
# 3905                           5.0
# 3906                           0.0
# 3907                          10.0
# 3908                          10.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 3904                                         10.0
# 3905                                         14.0
# 3906                                         30.0
# 3907                                        158.0
# 3908                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit  Sasaran Produk
# 0                                   4.0             1.0
# 1                                   3.0             2.0
# 2                                   7.0             1.0
# 3                                   5.0             3.0
# 4                                   4.0             1.0
# ...                                 ...             ...
# 3904                                5.0             2.0
# 3905                                5.0             1.0
# 3906                                7.0             2.0
# 3907                                9.0             2.0
# 3908                                4.0             1.0
#
# [2405 rows x 12 columns]

# %%
df_all.to_csv('handling.csv', index=False)

# %%
df_all.reset_index(drop=True, inplace=True)
# df_all['Log Total Aset'] = np.log10(df_all['Total Aset (Rp. Juta)'])
# df_all['Log Penjualan Rata-rata Tahunan'] = np.log10(df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)'])
# df_all['Log Kebutuhan Pembiayaan Kredit'] = np.log10(df_all['Kebutuhan Pembiayaan Kredit '])
# df_all['Log Nilai Aset Jaminan'] = np.log10(df_all['Nilai Aset yang data menjadi jaminan kredit'])

# %%
df_all
# Out:
#            Usaha /Produk Utama  Total Aset (Rp. Juta)  \
# 0                     Air Tebu                   5.00
# 1               Amplang Blitar                  71.50
# 2                      Bandrek                   0.00
# 3                    Bengkoang                  13.00
# 4            Beras Dan Sayuran                  89.00
# ...                        ...                    ...
# 2400             Jasa Internet                  22.50
# 2401                Service TV                  16.50
# 2402                    WARNET                  90.95
# 2403  LOKET PEMBAYARAN LISTRIK                 314.00
# 2404                    Warnet                   0.00
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Jumlah Tenaga Kerja  \
# 0                                        48.0                    2
# 1                                        60.0                    3
# 2                                         0.0                    1
# 3                                       402.0                   12
# 4                                       600.0                    3
# ...                                       ...                  ...
# 2400                                    704.0                    2
# 2401                                    115.0                    1
# 2402                                     94.5                    5
# 2403                                     40.0                    1
# 2404                                      0.0                    2
#
#                                    Sektor  Sistem Penjualan  \
# 0     Pertanian, Kehutanan, dan Perikanan               1.0
# 1     Pertanian, Kehutanan, dan Perikanan               1.0
# 2     Pertanian, Kehutanan, dan Perikanan               1.0
# 3     Pertanian, Kehutanan, dan Perikanan               3.0
# 4     Pertanian, Kehutanan, dan Perikanan               1.0
# ...                                   ...               ...
# 2400                            Lain-lain               1.0
# 2401                            Lain-lain               1.0
# 2402                            Lain-lain               1.0
# 2403                            Lain-lain               1.0
# 2404                            Lain-lain               1.0
#
#       Tingkat Pesaing Usaha  Proyeksi Pertumbuhan Penjualan  \
# 0                       1.0                            0.10
# 1                       1.0                            0.10
# 2                       0.0                            0.00
# 3                       2.0                            0.02
# 4                       1.0                            0.10
# ...                     ...                             ...
# 2400                    0.0                            0.20
# 2401                    1.0                            0.10
# 2402                    1.0                            0.80
# 2403                    2.0                            0.10
# 2404                    1.0                            0.00
#
#       Kebutuhan Pembiayaan Kredit   \
# 0                              5.0
# 1                             10.0
# 2                              5.0
# 3                              8.0
# 4                             10.0
# ...                            ...
# 2400                          10.0
# 2401                           5.0
# 2402                           0.0
# 2403                          10.0
# 2404                          10.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 2                                             6.0
# 3                                            10.0
# 4                                            24.0
# ...                                           ...
# 2400                                         10.0
# 2401                                         14.0
# 2402                                         30.0
# 2403                                        158.0
# 2404                                         12.0
#
#       Jumlah Dokumen Persyaratan Kredit  Sasaran Produk
# 0                                   4.0             1.0
# 1                                   3.0             2.0
# 2                                   7.0             1.0
# 3                                   5.0             3.0
# 4                                   4.0             1.0
# ...                                 ...             ...
# 2400                                5.0             2.0
# 2401                                5.0             1.0
# 2402                                7.0             2.0
# 2403                                9.0             2.0
# 2404                                4.0             1.0
#
# [2405 rows x 12 columns]

# %%
# df_all['Log Nilai Aset Jaminan'] = df_all['Nilai Aset yang data menjadi jaminan kredit'].replace(float('-inf'),0)

# %%
df_all['Rasio Efisiensi'] = df_all['Penjualan Rata-rata Per Tahun (Rp.Juta)']/df_all['Total Aset (Rp. Juta)']
df_all['Rasio Jaminan'] = df_all['Nilai Aset yang data menjadi jaminan kredit']/df_all['Kebutuhan Pembiayaan Kredit ']

# %%
def jenis_umkm(row):
    if(row['Total Aset (Rp. Juta)']<=50*10**6):
        val='Mikro'
    elif((row['Total Aset (Rp. Juta)']>50*10**6) & (row['Total Aset (Rp. Juta)']<=500*10**6)):
        val='Kecil'
    elif((row['Total Aset (Rp. Juta)']>500*10**6) & (row['Total Aset (Rp. Juta)']<=10*10**9)):
        val='Menengah'
    else:
        val= np.NaN
    return val

# %%
df_all['Jenis UMKM']=df_all.apply(jenis_umkm,axis=1)

# %%
df_all.dropna(inplace=True)

# %%
df_all.columns
# Out:
# Index(['Usaha /Produk Utama', 'Total Aset (Rp. Juta)',
#        'Penjualan Rata-rata Per Tahun (Rp.Juta)', 'Jumlah Tenaga Kerja',
#        'Sektor', 'Sistem Penjualan', 'Tingkat Pesaing Usaha',
#        'Proyeksi Pertumbuhan Penjualan', 'Kebutuhan Pembiayaan Kredit ',
#        'Nilai Aset yang data menjadi jaminan kredit',
#        'Jumlah Dokumen Persyaratan Kredit', 'Sasaran Produk',
#        'rasio_efisiensi', 'rasio_jaminan', 'jenis_umkm'],
#       dtype='object')

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
seleksi = df_all[['Total Aset (Rp. Juta)',
       'Penjualan Rata-rata Per Tahun (Rp.Juta)', 'Jumlah Tenaga Kerja',
       'Sektor', 'Sistem Penjualan', 'Tingkat Pesaing Usaha',
       'Proyeksi Pertumbuhan Penjualan', 'Kebutuhan Pembiayaan Kredit ',
       'Nilai Aset yang data menjadi jaminan kredit',
       'Jumlah Dokumen Persyaratan Kredit', 'Sasaran Produk',
       'Rasio Jaminan', 'Rasio Efisiensi', 'Jenis UMKM']]

# %%
skenario1 = pd.get_dummies(seleksi, columns=['Jenis UMKM', 'Sektor'], drop_first=True)

# %%
skenario1
# Out:
#       Total Aset (Rp. Juta)  Penjualan Rata-rata Per Tahun (Rp.Juta)  \
# 0                      5.00                                     48.0
# 1                     71.50                                     60.0
# 3                     13.00                                    402.0
# 4                     89.00                                    600.0
# 6                    153.00                                    160.0
# ...                     ...                                      ...
# 2399                  16.30                                    216.0
# 2400                  22.50                                    704.0
# 2401                  16.50                                    115.0
# 2402                  90.95                                     94.5
# 2403                 314.00                                     40.0
#
#       Jumlah Tenaga Kerja  Sistem Penjualan  Tingkat Pesaing Usaha  \
# 0                       2               1.0                    1.0
# 1                       3               1.0                    1.0
# 3                      12               3.0                    2.0
# 4                       3               1.0                    1.0
# 6                       1               2.0                    1.0
# ...                   ...               ...                    ...
# 2399                    1               1.0                    1.0
# 2400                    2               1.0                    0.0
# 2401                    1               1.0                    1.0
# 2402                    5               1.0                    1.0
# 2403                    1               1.0                    2.0
#
#       Proyeksi Pertumbuhan Penjualan  Kebutuhan Pembiayaan Kredit   \
# 0                               0.10                           5.0
# 1                               0.10                          10.0
# 3                               0.02                           8.0
# 4                               0.10                          10.0
# 6                               1.00                          10.0
# ...                              ...                           ...
# 2399                            0.10                          10.0
# 2400                            0.20                          10.0
# 2401                            0.10                           5.0
# 2402                            0.80                           0.0
# 2403                            0.10                          10.0
#
#       Nilai Aset yang data menjadi jaminan kredit  \
# 0                                             4.0
# 1                                           200.0
# 3                                            10.0
# 4                                            24.0
# 6                                           150.0
# ...                                           ...
# 2399                                          9.0
# 2400                                         10.0
# 2401                                         14.0
# 2402                                         30.0
# 2403                                        158.0
#
#       Jumlah Dokumen Persyaratan Kredit  Sasaran Produk  rasio_efisiensi  \
# 0                                   4.0             1.0         9.600000
# 1                                   3.0             2.0         0.839161
# 3                                   5.0             3.0        30.923077
# 4                                   4.0             1.0         6.741573
# 6                                   7.0             2.0         1.045752
# ...                                 ...             ...              ...
# 2399                                4.0             1.0        13.251534
# 2400                                5.0             2.0        31.288889
# 2401                                5.0             1.0         6.969697
# 2402                                7.0             2.0         1.039032
# 2403                                9.0             2.0         0.127389
#
#       rasio_jaminan  Sektor_Lain-lain  \
# 0              0.80                 0
# 1             20.00                 0
# 3              1.25                 0
# 4              2.40                 0
# 6             15.00                 0
# ...             ...               ...
# 2399           0.90                 1
# 2400           1.00                 1
# 2401           2.80                 1
# 2402            inf                 1
# 2403          15.80                 1
#
#       Sektor_Penyediaan Akomodasi dan Penyediaan Makan Minum  \
# 0                                                     0
# 1                                                     0
# 3                                                     0
# 4                                                     0
# 6                                                     0
# ...                                                 ...
# 2399                                                  0
# 2400                                                  0
# 2401                                                  0
# 2402                                                  0
# 2403                                                  0
#
#       Sektor_Perdagangan dan Perawatan Kendaraan  \
# 0                                              0
# 1                                              0
# 3                                              0
# 4                                              0
# 6                                              0
# ...                                          ...
# 2399                                           0
# 2400                                           0
# 2401                                           0
# 2402                                           0
# 2403                                           0
#
#       Sektor_Pertanian, Kehutanan, dan Perikanan
# 0                                              1
# 1                                              1
# 3                                              1
# 4                                              1
# 6                                              1
# ...                                          ...
# 2399                                           0
# 2400                                           0
# 2401                                           0
# 2402                                           0
# 2403                                           0
#
# [2072 rows x 16 columns]

# %%
plt.figure(figsize=(10,5))
ax = sns.heatmap(skenario1.corr(),annot=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=30,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'Total Aset (Rp. Juta)'),
#  Text(1.5, 0, 'Penjualan Rata-rata Per Tahun (Rp.Juta)'),
#  Text(2.5, 0, 'Jumlah Tenaga Kerja'),
#  Text(3.5, 0, 'Sistem Penjualan'),
#  Text(4.5, 0, 'Tingkat Pesaing Usaha'),
#  Text(5.5, 0, 'Proyeksi Pertumbuhan Penjualan'),
#  Text(6.5, 0, 'Kebutuhan Pembiayaan Kredit '),
#  Text(7.5, 0, 'Nilai Aset yang data menjadi jaminan kredit'),
#  Text(8.5, 0, 'Jumlah Dokumen Persyaratan Kredit'),
#  Text(9.5, 0, 'Sasaran Produk'),
#  Text(10.5, 0, 'rasio_efisiensi'),
#  Text(11.5, 0, 'rasio_jaminan'),
#  Text(12.5, 0, 'Sektor_Lain-lain'),
#  Text(13.5, 0, 'Sektor_Penyediaan Akomodasi dan Penyediaan Makan Minum'),
#  Text(14.5, 0, 'Sektor_Perdagangan dan Perawatan Kendaraan'),
#  Text(15.5, 0, 'Sektor_Pertanian, Kehutanan, dan Perikanan')]

# %%
df_all.columns
# Out:
# Index(['Usaha /Produk Utama', 'Total Aset (Rp. Juta)',
#        'Penjualan Rata-rata Per Tahun (Rp.Juta)', 'Jumlah Tenaga Kerja',
#        'Sektor', 'Sistem Penjualan', 'Tingkat Pesaing Usaha',
#        'Proyeksi Pertumbuhan Penjualan', 'Kebutuhan Pembiayaan Kredit ',
#        'Nilai Aset yang data menjadi jaminan kredit',
#        'Jumlah Dokumen Persyaratan Kredit', 'Sasaran Produk',
#        'rasio_efisiensi', 'rasio_jaminan', 'jenis_umkm'],
#       dtype='object')

# %%
skenario2 = seleksi[['Jumlah Tenaga Kerja', 'Total Aset (Rp. Juta)','Penjualan Rata-rata Per Tahun (Rp.Juta)',
                     'Kebutuhan Pembiayaan Kredit ', 'Nilai Aset yang data menjadi jaminan kredit', 'Rasio Jaminan', 'Rasio Efisiensi', 'Proyeksi Pertumbuhan Penjualan']]

# %%
korelasi = skenario2.corr()

# %%
for i in korelasi.columns:
    temp=abs(korelasi[i])
    col=temp[(temp>0.45) & (temp!=1)].index
    if col.empty:
        a=0
    else:
        print(i,col)
# Out:
# Total Aset (Rp. Juta) Index(['Nilai Aset yang data menjadi jaminan kredit'], dtype='object')
# Nilai Aset yang data menjadi jaminan kredit Index(['Total Aset (Rp. Juta)', 'rasio_jaminan'], dtype='object')
# rasio_jaminan Index(['Nilai Aset yang data menjadi jaminan kredit'], dtype='object')

# %%
skenario3 = seleksi[['Kebutuhan Pembiayaan Kredit ', 'Proyeksi Pertumbuhan Penjualan',
                     'Rasio Jaminan', 'Rasio Efisiensi']]

# %%
korelasi = skenario3.corr()

# %%
korelasi
# Out:
#                                 Kebutuhan Pembiayaan Kredit   \
# Kebutuhan Pembiayaan Kredit                         1.000000
# Proyeksi Pertumbuhan Penjualan                     -0.054643
# rasio_jaminan                                      -0.195496
# rasio_efisiensi                                     0.029973
#
#                                 Proyeksi Pertumbuhan Penjualan  rasio_jaminan  \
# Kebutuhan Pembiayaan Kredit                          -0.054643      -0.195496
# Proyeksi Pertumbuhan Penjualan                        1.000000       0.049451
# rasio_jaminan                                         0.049451       1.000000
# rasio_efisiensi                                      -0.000782      -0.006652
#
#                                 rasio_efisiensi
# Kebutuhan Pembiayaan Kredit            0.029973
# Proyeksi Pertumbuhan Penjualan        -0.000782
# rasio_jaminan                         -0.006652
# rasio_efisiensi                        1.000000

# %%
for i in korelasi.columns:
    temp=abs(korelasi[i])
    col=temp[(temp>0.47) & (temp!=1)].index
    if col.empty:
        a=0
    else:
        print(i,col)

# %%
plt.figure(figsize=(10,5))
ax = sns.heatmap(skenario2.corr(),annot=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=30,
    horizontalalignment='right'
)
ax.set_title('Non-Collinearity Attributes ', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Non-Collinearity Attributes ')

# %%
data = skenario2

# %%
data
# Out:
#       Jumlah Tenaga Kerja  Total Aset (Rp. Juta)  \
# 0                       2                   5.00
# 1                       3                  71.50
# 3                      12                  13.00
# 4                       3                  89.00
# 6                       1                 153.00
# ...                   ...                    ...
# 2399                    1                  16.30
# 2400                    2                  22.50
# 2401                    1                  16.50
# 2402                    5                  90.95
# 2403                    1                 314.00
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Kebutuhan Pembiayaan Kredit   \
# 0                                        48.0                           5.0
# 1                                        60.0                          10.0
# 3                                       402.0                           8.0
# 4                                       600.0                          10.0
# 6                                       160.0                          10.0
# ...                                       ...                           ...
# 2399                                    216.0                          10.0
# 2400                                    704.0                          10.0
# 2401                                    115.0                           5.0
# 2402                                     94.5                           0.0
# 2403                                     40.0                          10.0
#
#       Nilai Aset yang data menjadi jaminan kredit  rasio_efisiensi  \
# 0                                             4.0         9.600000
# 1                                           200.0         0.839161
# 3                                            10.0        30.923077
# 4                                            24.0         6.741573
# 6                                           150.0         1.045752
# ...                                           ...              ...
# 2399                                          9.0        13.251534
# 2400                                         10.0        31.288889
# 2401                                         14.0         6.969697
# 2402                                         30.0         1.039032
# 2403                                        158.0         0.127389
#
#       rasio_jaminan  Proyeksi Pertumbuhan Penjualan
# 0              0.80                            0.10
# 1             20.00                            0.10
# 3              1.25                            0.02
# 4              2.40                            0.10
# 6             15.00                            1.00
# ...             ...                             ...
# 2399           0.90                            0.10
# 2400           1.00                            0.20
# 2401           2.80                            0.10
# 2402            inf                            0.80
# 2403          15.80                            0.10
#
# [2072 rows x 8 columns]

# %%
data.index[np.isinf(data).any(1)]
# Out:
# Int64Index([  11,   15,   16,   17,   25,   28,   32,   34,   39,   54,
#             ...
#             2361, 2370, 2371, 2373, 2374, 2386, 2387, 2388, 2389, 2402],
#            dtype='int64', length=374)

# %%
data=data.replace(float('inf'),0)

# %%
data
# Out:
#       Jumlah Tenaga Kerja  Total Aset (Rp. Juta)  \
# 0                       2                   5.00
# 1                       3                  71.50
# 3                      12                  13.00
# 4                       3                  89.00
# 6                       1                 153.00
# ...                   ...                    ...
# 2399                    1                  16.30
# 2400                    2                  22.50
# 2401                    1                  16.50
# 2402                    5                  90.95
# 2403                    1                 314.00
#
#       Penjualan Rata-rata Per Tahun (Rp.Juta)  Kebutuhan Pembiayaan Kredit   \
# 0                                        48.0                           5.0
# 1                                        60.0                          10.0
# 3                                       402.0                           8.0
# 4                                       600.0                          10.0
# 6                                       160.0                          10.0
# ...                                       ...                           ...
# 2399                                    216.0                          10.0
# 2400                                    704.0                          10.0
# 2401                                    115.0                           5.0
# 2402                                     94.5                           0.0
# 2403                                     40.0                          10.0
#
#       Nilai Aset yang data menjadi jaminan kredit  rasio_efisiensi  \
# 0                                             4.0         9.600000
# 1                                           200.0         0.839161
# 3                                            10.0        30.923077
# 4                                            24.0         6.741573
# 6                                           150.0         1.045752
# ...                                           ...              ...
# 2399                                          9.0        13.251534
# 2400                                         10.0        31.288889
# 2401                                         14.0         6.969697
# 2402                                         30.0         1.039032
# 2403                                        158.0         0.127389
#
#       rasio_jaminan  Proyeksi Pertumbuhan Penjualan
# 0              0.80                            0.10
# 1             20.00                            0.10
# 3              1.25                            0.02
# 4              2.40                            0.10
# 6             15.00                            1.00
# ...             ...                             ...
# 2399           0.90                            0.10
# 2400           1.00                            0.20
# 2401           2.80                            0.10
# 2402           0.00                            0.80
# 2403          15.80                            0.10
#
# [2072 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
x_array = np.array(data)
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(x_array)

# %%
def tuningKmeans(data,maxn,inits):
    best_score=-9999999
    waktu=datetime.datetime.now()
    namafile=str(waktu.strftime("%Y%m%d-%H%M%S"))+'_log_'+str(maxn)+str(inits)+'kmeans.txt'
    f = open(namafile,'w',encoding="utf-8")
    for init in inits:
        for i in range(2,maxn+1):
#             print(i,init)
            km = KMeans(n_clusters=i, random_state=100,init=init)
            pred = km.fit_predict(data)
            silhouette_avg = silhouette_score(data, pred)
            out='Silhouette score :'+str(silhouette_avg)+' dengan n='+str(i)+' tipe init= '+str(init)+'\n'
            print(out)
            f.write(out)
            if(silhouette_avg>best_score):
                best_score=silhouette_avg
                best_model=km
                best_pred=pred
                best_n=i
                best_init=init
    out='Best Model didapatkan dari n='+str(best_n)+', dengan init='+str(best_init)+', dengan score='+str(best_score)+'\n'
    print(out)
    f.write(out)
    f.close()
    return(best_model,best_pred)

# %%
maxn=5
inits=['k-means++','random']
model,pred=tuningKmeans(data_scaled,maxn,inits)
# Out:
# Silhouette score :0.49760734513547256 dengan n=2 tipe init= k-means++
#
# Silhouette score :0.4589885979350643 dengan n=3 tipe init= k-means++
#
# Silhouette score :0.4492129529955155 dengan n=4 tipe init= k-means++
#
# Silhouette score :0.4590893326007179 dengan n=5 tipe init= k-means++
#
# Silhouette score :0.49760734513547256 dengan n=2 tipe init= random
#
# Silhouette score :0.4589885979350643 dengan n=3 tipe init= random
#
# Silhouette score :0.4492129529955155 dengan n=4 tipe init= random
#
# Silhouette score :0.45910635649136156 dengan n=5 tipe init= random
#
# Best Model didapatkan dari n=2, dengan init=k-means++, dengan score=0.49760734513547256

# %%
def tuningHierar(data,maxn,linkages):
    best_score=-9999999
    waktu=datetime.datetime.now()
    namafile=str(waktu.strftime("%Y%m%d-%H%M%S"))+'_log_'+str(maxn)+str(linkages)+'AggloClust.txt'
    f = open(namafile,'w',encoding="utf-8")
    for linkage in linkages:
        for i in range(2,maxn+1):
    #             print(i,init)
            hie=AgglomerativeClustering(n_clusters=i,linkage=linkage)
            pred = hie.fit_predict(data)
            silhouette_avg = silhouette_score(data, pred)
            out='Silhouette score :'+str(silhouette_avg)+' dengan n='+str(i)+' tipe linkage= '+str(linkage)+'\n'
            print(out)
            f.write(out)
            if(silhouette_avg>best_score):
                best_score=silhouette_avg
                best_model=hie
                best_pred=pred
                best_n=i
                best_linkage=linkage
    out='Best Model didapatkan dari n='+str(best_n)+', dengan score='+str(best_score)+' tipe linkage= '+str(best_linkage)+'\n'
    print(out)
    f.write(out)
    f.close()
    return(best_model,best_pred)

# %%
maxn=5
linkages=['ward','complete']
model,pred=tuningHierar(data_scaled,maxn,linkages)
# Out:
# Silhouette score :0.4905429163229505 dengan n=2 tipe linkage= ward
#
# Silhouette score :0.45451508273041097 dengan n=3 tipe linkage= ward
#
# Silhouette score :0.4519796429690911 dengan n=4 tipe linkage= ward
#
# Silhouette score :0.45656717918004164 dengan n=5 tipe linkage= ward
#
# Silhouette score :0.6280599696415775 dengan n=2 tipe linkage= complete
#
# Silhouette score :0.4843718575851432 dengan n=3 tipe linkage= complete
#
# Silhouette score :0.4805676832893757 dengan n=4 tipe linkage= complete
#
# Silhouette score :0.430761413120956 dengan n=5 tipe linkage= complete
#
# Best Model didapatkan dari n=2, dengan score=0.6280599696415775 tipe linkage= complete

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(data)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
n=2

# %%
# %%time
hie = AgglomerativeClustering(n_clusters=2,linkage='complete')
pred_h = hie.fit_predict(data_scaled)
silhouette_avg = silhouette_score(data_scaled, pred_h)
print(silhouette_avg)
# Out:
# 0.6280599696415775
# Wall time: 504 ms

# %%
# %%time
km = KMeans(n_clusters=n, random_state=0,init='k-means++')
pred_p = km.fit_predict(data_scaled)
silhouette_avg = silhouette_score(data_scaled, pred_p)
print(silhouette_avg)
# Out:
# 0.49760734513547256
# Wall time: 224 ms

# %%
# %%time
km = KMeans(n_clusters=n, random_state=0,init='random')
pred_r = km.fit_predict(data_scaled)
silhouette_avg = silhouette_score(data_scaled, pred_r)
print(silhouette_avg)
# Out:
# 0.49760734513547256
# Wall time: 239 ms

# %%
korr = data.copy()

# %%
korr['Class_p']= pred_p
korr['Class_r']= pred_r

# %%
korelasi = korr.corr(method='spearman')

# %%
corr_p=abs(korelasi['Class_p'])

# %%
corr_p
# Out:
# Jumlah Tenaga Kerja                            0.064424
# Total Aset (Rp. Juta)                          0.024222
# Penjualan Rata-rata Per Tahun (Rp.Juta)        0.134774
# Kebutuhan Pembiayaan Kredit                    0.905710
# Nilai Aset yang data menjadi jaminan kredit    0.019035
# rasio_efisiensi                                0.105605
# rasio_jaminan                                  0.225993
# Proyeksi Pertumbuhan Penjualan                 0.074260
# Class_p                                        1.000000
# Class_r                                        1.000000
# Name: Class_p, dtype: float64

# %%
corr_r=abs(korelasi['Class_r'])
corr_r
# Out:
# Jumlah Tenaga Kerja                            0.064424
# Total Aset (Rp. Juta)                          0.024222
# Penjualan Rata-rata Per Tahun (Rp.Juta)        0.134774
# Kebutuhan Pembiayaan Kredit                    0.905710
# Nilai Aset yang data menjadi jaminan kredit    0.019035
# rasio_efisiensi                                0.105605
# rasio_jaminan                                  0.225993
# Proyeksi Pertumbuhan Penjualan                 0.074260
# Class_p                                        1.000000
# Class_r                                        1.000000
# Name: Class_r, dtype: float64

# %%
x = data_scaled

# %%
# plt.scatter(x[:, 0], x[:, 1], c=pred_p, s=5)

centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=1);

# %%
labels_best = km.labels_

# %%
labels_best
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
data['Label'] = labels_best
data[data['Label'] == 1].describe().mean()
# Out:
# Jumlah Tenaga Kerja                            133.332209
# Total Aset (Rp. Juta)                          316.898371
# Penjualan Rata-rata Per Tahun (Rp.Juta)        325.148224
# Kebutuhan Pembiayaan Kredit                    127.390513
# Nilai Aset yang data menjadi jaminan kredit    304.836511
# rasio_efisiensi                                225.755934
# rasio_jaminan                                  162.247318
# Proyeksi Pertumbuhan Penjualan                 132.847413
# Label                                          125.625000
# dtype: float64

# %%
data[data['Label'] == 0].describe().mean()
# Out:
# Jumlah Tenaga Kerja                             141.183141
# Total Aset (Rp. Juta)                           467.473618
# Penjualan Rata-rata Per Tahun (Rp.Juta)         347.209896
# Kebutuhan Pembiayaan Kredit                     141.304383
# Nilai Aset yang data menjadi jaminan kredit     308.883199
# rasio_efisiensi                                1519.478063
# rasio_jaminan                                   153.998866
# Proyeksi Pertumbuhan Penjualan                  134.348783
# Label                                           134.125000
# dtype: float64

# %%
from re import sub  
def title_style(my_string):  
    my_string = sub(r"(_|-)+", " ", my_string).title() 
    return my_string[0].upper() + my_string[1:]

# %%
import matplotlib.pyplot as plt
import numpy as np

label0_means = data[data['Label'] == 0].describe().mean()
label1_means = data[data['Label'] == 1].describe().mean()

x = np.arange(len(data.columns))
width = 0.4 
fig, ax = plt.subplots()
rects1 = ax.barh(x - width/2, label0_means, width, label='0')
rects2 = ax.barh(x + width/2, label1_means, width, label='1')

ax.set_title('Insight by Cluster')
ax.set_yticks(x, [title_style(x).replace('_', ' ') for x in data.columns])
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

plt.show()
